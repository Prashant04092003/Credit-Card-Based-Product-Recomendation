# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('users.csv')
df1 = pd.read_csv('cards.csv')
df2 = pd.read_csv('trans.csv')
df3 = pd.read_csv('fraud.csv')
df4 = pd.read_csv('segmentation.csv')
df5 = pd.read_csv('recommendations.csv')

# %%
df.head()
# Out:
#            Person  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0  Hazel Robinson           53              66        1966           11
# 1      Sasha Sadr           53              68        1966           12
# 2      Saanvi Lee           81              67        1938           11
# 3   Everlee Clark           63              63        1957            1
# 4   Kyle Peterson           43              70        1976            9
#
#    Gender                   Address  Apartment           City State  Zipcode  \
# 0  Female             462 Rose Lane        NaN       La Verne    CA    91750
# 1  Female    3606 Federal Boulevard        NaN    Little Neck    NY    11363
# 2  Female           766 Third Drive        NaN    West Covina    CA    91792
# 3  Female          3 Madison Street        NaN       New York    NY    10069
# 4    Male  9620 Valley Stream Drive        NaN  San Francisco    CA    94117
#
# ...

# %%
df.columns
# Out:
# Index(['Person', 'Current Age', 'Retirement Age', 'Birth Year', 'Birth Month',
#        'Gender', 'Address', 'Apartment', 'City', 'State', 'Zipcode',
#        'Latitude', 'Longitude', 'Per Capita Income - Zipcode',
#        'Yearly Income - Person', 'Total Debt', 'FICO Score',
#        'Num Credit Cards'],
#       dtype='object')

# %%
df1.head()
# Out:
#    User  CARD INDEX  Card Brand        Card Type       Card Number  Expires  \
# 0     0           0        Visa            Debit  4344676511950444  12/2022
# 1     0           1        Visa            Debit  4956965974959986  12/2020
# 2     0           2        Visa            Debit  4582313478255491  02/2024
# 3     0           3        Visa           Credit  4879494103069057  08/2024
# 4     0           4  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# 0  623      YES             2       $24295        09/2002
# 1  393      YES             2       $21968        04/2014
# 2  719      YES             2       $46414        07/2003
# 3  693       NO             1       $12400        01/2003
# 4   75      YES             1          $28        09/2008
#
#    Year PIN last Changed Card on Dark Web
# 0                   2008               No
# 1                   2014               No
# ...

# %%
df1.columns
# Out:
# Index(['User', 'CARD INDEX', 'Card Brand', 'Card Type', 'Card Number',
#        'Expires', 'CVV', 'Has Chip', 'Cards Issued', 'Credit Limit',
#        'Acct Open Date', 'Year PIN last Changed', 'Card on Dark Web'],
#       dtype='object')

# %%
df2.head()
# Out:
#    User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0     0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1     0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2     0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3     0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4     0     0  2002      9    3  06:23  $104.71  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300     NaN
# 1  -727612092139916043  Monterey Park             CA  91754.0  5411     NaN
# 2  -727612092139916043  Monterey Park             CA  91754.0  5411     NaN
# 3  3414527459579106770  Monterey Park             CA  91754.0  5651     NaN
# 4  5817218446178736267       La Verne             CA  91750.0  5912     NaN
#
#   Is Fraud?
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No

# %%
df2.columns
# Out:
# Index(['User', 'Card', 'Year', 'Month', 'Day', 'Time', 'Amount', 'Use Chip',
#        'Merchant Name', 'Merchant City', 'Merchant State', 'Zip', 'MCC',
#        'Errors?', 'Is Fraud?'],
#       dtype='object')

# %%
df3.head()
# Out:
#    User        Merchant Name  Year  Month  Day   Time  \
# 0     0  1913477460590765860  2017      5   15  06:19
# 1     0   -34551508091458520  2017      5   15  06:38
# 2     0   -86825621511712373  2017      5   15  10:49
# 3     0  -727612092139916043  2017      5   16  06:30
# 4     0  4060646732831064559  2017      5   18  06:17
#
#    is_new_merchant_for_user  is_new_mcc_for_user  tx_count_24h  \
# 0                         0                    1           3.0
# 1                         0                    1           2.0
# 2                         0                    1           3.0
# 3                         0                    1           3.0
# 4                         0                    0           3.0
#
#    time_since_prev_tx  amount_vs_user_median  Is Fraud?  fraud_score  \
# 0             73740.0               2.262394          0     0.001149
# 1              1140.0               1.197183          0     0.001175
# ...

# %%
df3.columns
# Out:
# Index(['User', 'Merchant Name', 'Year', 'Month', 'Day', 'Time',
#        'is_new_merchant_for_user', 'is_new_mcc_for_user', 'tx_count_24h',
#        'time_since_prev_tx', 'amount_vs_user_median', 'Is Fraud?',
#        'fraud_score', 'fraud_band', 'fraud_action'],
#       dtype='object')

# %%
df4.head()
# Out:
#    User  txn_count  total_spend  avg_txn_amount  spend_cv  category_entropy  \
# 0     0      19963   1622991.69       81.299989  1.158169          2.034541
# 1     1       8919    723491.89       81.118050  1.932797          1.803725
# 2     2      41978   1475933.36       35.159687  1.544341          1.448890
# 3     3      10117   1186497.51      117.277603  2.290757          1.830075
# 4     4      18542   1798790.91       97.011698  1.428895          1.609290
#
#    share_Groceries  share_Dining_Food  share_Transport_Fuel  \
# 0         0.177282           0.054720              0.072794
# 1         0.047638           0.084613              0.034325
# 2         0.057180           0.026455              0.114227
# 3         0.071181           0.117604              0.016303
# 4         0.070531           0.020382              0.014073
#
#    share_Retail_Apparel  ...  share_Digital_Subscriptions  \
# 0              0.228775  ...                     0.052263
# ...

# %%
df4.columns
# Out:
# Index(['User', 'txn_count', 'total_spend', 'avg_txn_amount', 'spend_cv',
#        'category_entropy', 'share_Groceries', 'share_Dining_Food',
#        'share_Transport_Fuel', 'share_Retail_Apparel',
#        'share_Healthcare_Wellness', 'share_Utilities_Bills',
#        'share_Digital_Subscriptions', 'share_Travel_Lodging',
#        'share_Entertainment_Leisure', 'num_cards', 'total_credit_limit',
#        'avg_credit_limit', 'avg_fraud_score', 'pct_high', 'pct_critical',
#        'cluster'],
#       dtype='object')

# %%
df5.head()
# Out:
#    user_id  cluster  rank    card_id            card_name       brand  \
# 0        0      3.0     1  C3_AMEX_1  Amex Platinum Elite        Amex
# 1        0      3.0     2  C1_AMEX_1      Amex Drive Gold        Amex
# 2        0      3.0     3  C0_AMEX_1     Amex Blue Retail        Amex
# 3        1      0.0     1  C0_VISA_2  Visa Lifestyle Plus        Visa
# 4        1      0.0     2    C0_MC_1        MC Urban Life  Mastercard
#
#    card_tier  annual_fee   apr  final_score  cluster_id  \
# 0    premium         550  16.9  7418.508853           3
# 1    premium         150  17.9  7407.975136           1
# 2   cashback           0  17.9  7405.837430           0
# 3  lifestyle          95  18.5  3298.505698           0
# 4  lifestyle          79  18.9  3297.573270           0
#
#                              persona
# 0   Affluent Multi-Category Spenders
# 1   Affluent Multi-Category Spenders
# 2   Affluent Multi-Category Spenders
# 3  Retail-Centric Lifestyle Spenders
# ...

# %%
df5.columns
# Out:
# Index(['user_id', 'cluster', 'rank', 'card_id', 'card_name', 'brand',
#        'card_tier', 'annual_fee', 'apr', 'final_score', 'cluster_id',
#        'persona'],
#       dtype='object')

# %%
df6 = pd.read_csv('card_master_table.csv')

# %%
df6.head()
# Out:
#      card_id              card_name       brand  cluster_id  min_fico  \
# 0  C0_VISA_1  Visa Everyday Rewards        Visa           0       660
# 1  C0_VISA_2    Visa Lifestyle Plus        Visa           0       700
# 2    C0_MC_1          MC Urban Life  Mastercard           0       690
# 3  C0_AMEX_1       Amex Blue Retail        Amex           0       700
# 4  C0_DISC_1     Discover Retail It    Discover           0       660
#
#    max_fico  annual_fee   apr  credit_limit_min  credit_limit_max  \
# 0       740           0  19.9              2000              6000
# 1       780          95  18.5              8000             15000
# 2       760          79  18.9              7000             12000
# 3       800           0  17.9              5000             10000
# 4       740           0  20.9              2000              5000
#
#    reward_grocery  reward_dining  reward_fuel  reward_travel  reward_retail  \
# ...

# %%
df6.columns
# Out:
# Index(['card_id', 'card_name', 'brand', 'cluster_id', 'min_fico', 'max_fico',
#        'annual_fee', 'apr', 'credit_limit_min', 'credit_limit_max',
#        'reward_grocery', 'reward_dining', 'reward_fuel', 'reward_travel',
#        'reward_retail', 'reward_digital', 'reward_other', 'card_tier'],
#       dtype='object')
